# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("fifa_world cup.csv")

# %%
df.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions
# 0
# 1
# 2
# 3
# 4

# %%
df.tail()
# Out:
#         Year Datetime           Stage                          Stadium  \
# 1069  2026.0      NaN  Quarter-finals  GEHA Field at Arrowhead Stadium
# 1070  2026.0      NaN     Semi-finals                     AT&T Stadium
# 1071  2026.0      NaN     Semi-finals            Mercedes-Benz Stadium
# 1072  2026.0      NaN     Third Place                    Miami Stadium
# 1073  2026.0      NaN          Finals      New York New Jersey Stadium
#
#              City Home Team Name  Home Team Goals  Away Team Goals  \
# 1069  Kansas City      Argentina              3.0              1.0
# 1070       Dallas         France              0.0              2.0
# 1071      Atlanta        England              1.0              2.0
# 1072        Miami         France              4.0              6.0
# 1073   New Jersey          Spain              1.0              0.0
#
#      Away Team Name                  Win conditions
# 1069    Switzerland  Argentina win after extra time
# 1070          Spain
# ...

# %%
df.shape
# Out:
# (1074, 10)

# %%
df.size
# Out:
# 10740

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year               float64
# Datetime            object
# Stage               object
# Stadium             object
# City                object
# Home Team Name      object
# Home Team Goals    float64
# Away Team Goals    float64
# Away Team Name      object
# Win conditions      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             1074 non-null   float64
#  1   Datetime         980 non-null    object
#  2   Stage            1074 non-null   object
#  3   Stadium          1074 non-null   object
#  4   City             1074 non-null   object
#  5   Home Team Name   1074 non-null   object
#  6   Home Team Goals  1074 non-null   float64
#  7   Away Team Goals  1074 non-null   float64
#  8   Away Team Name   1074 non-null   object
#  9   Win conditions   1074 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 84.0+ KB

# %%
df.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals
# count  1074.000000      1074.000000      1074.000000
# mean   1992.830540         1.761639         1.059590
# std      25.143376         1.584812         1.091433
# min    1930.000000         0.000000         0.000000
# 25%    1974.000000         1.000000         0.000000
# 50%    1998.000000         1.000000         1.000000
# 75%    2014.000000         3.000000         2.000000
# max    2026.000000        10.000000         7.000000

# %%
df=df.drop("Datetime",axis=1)
print(df)
# Out:
#         Year           Stage                          Stadium         City  \
# 0     1930.0         Group 1                          Pocitos  Montevideo
# 1     1930.0         Group 4                   Parque Central  Montevideo
# 2     1930.0         Group 2                   Parque Central  Montevideo
# 3     1930.0         Group 3                          Pocitos  Montevideo
# 4     1930.0         Group 1                   Parque Central  Montevideo
# ...      ...             ...                              ...          ...
# 1069  2026.0  Quarter-finals  GEHA Field at Arrowhead Stadium  Kansas City
# 1070  2026.0     Semi-finals                     AT&T Stadium       Dallas
# 1071  2026.0     Semi-finals            Mercedes-Benz Stadium      Atlanta
# 1072  2026.0     Third Place                    Miami Stadium        Miami
# 1073  2026.0          Finals      New York New Jersey Stadium   New Jersey
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
df.head()
# Out:
#      Year    Stage         Stadium         City Home Team Name  \
# 0  1930.0  Group 1         Pocitos  Montevideo          France
# 1  1930.0  Group 4  Parque Central  Montevideo             USA
# 2  1930.0  Group 2  Parque Central  Montevideo      Yugoslavia
# 3  1930.0  Group 3         Pocitos  Montevideo         Romania
# 4  1930.0  Group 1  Parque Central  Montevideo       Argentina
#
#    Home Team Goals  Away Team Goals Away Team Name Win conditions
# 0              4.0              1.0         Mexico
# 1              3.0              0.0        Belgium
# 2              2.0              1.0         Brazil
# 3              3.0              1.0           Peru
# 4              1.0              0.0         France

# %%
df.tail()
# Out:
#         Year           Stage                          Stadium         City  \
# 1069  2026.0  Quarter-finals  GEHA Field at Arrowhead Stadium  Kansas City
# 1070  2026.0     Semi-finals                     AT&T Stadium       Dallas
# 1071  2026.0     Semi-finals            Mercedes-Benz Stadium      Atlanta
# 1072  2026.0     Third Place                    Miami Stadium        Miami
# 1073  2026.0          Finals      New York New Jersey Stadium   New Jersey
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 1069      Argentina              3.0              1.0    Switzerland
# 1070         France              0.0              2.0          Spain
# 1071        England              1.0              2.0      Argentina
# 1072         France              4.0              6.0        England
# 1073          Spain              1.0              0.0      Argentina
#
#                       Win conditions
# 1069  Argentina win after extra time
# 1070
# 1071
# 1072
# ...

# %%
df.isnull().sum()
# Out:
# Year               0
# Stage              0
# Stadium            0
# City               0
# Home Team Name     0
# Home Team Goals    0
# Away Team Goals    0
# Away Team Name     0
# Win conditions     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 16

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Year"]
# Out:
# 0       1930.0
# 1       1930.0
# 2       1930.0
# 3       1930.0
# 4       1930.0
#          ...
# 1069    2026.0
# 1070    2026.0
# 1071    2026.0
# 1072    2026.0
# 1073    2026.0
# Name: Year, Length: 1058, dtype: float64

# %%
df[["Year","Stage","Stadium"]]
# Out:
#         Year           Stage                          Stadium
# 0     1930.0         Group 1                          Pocitos
# 1     1930.0         Group 4                   Parque Central
# 2     1930.0         Group 2                   Parque Central
# 3     1930.0         Group 3                          Pocitos
# 4     1930.0         Group 1                   Parque Central
# ...      ...             ...                              ...
# 1069  2026.0  Quarter-finals  GEHA Field at Arrowhead Stadium
# 1070  2026.0     Semi-finals                     AT&T Stadium
# 1071  2026.0     Semi-finals            Mercedes-Benz Stadium
# 1072  2026.0     Third Place                    Miami Stadium
# 1073  2026.0          Finals      New York New Jersey Stadium
#
# [1058 rows x 3 columns]

# %%
df.iloc[0]
# Out:
# Year                    1930.0
# Stage                  Group 1
# Stadium                Pocitos
# City               Montevideo
# Home Team Name          France
# Home Team Goals            4.0
# Away Team Goals            1.0
# Away Team Name          Mexico
# Win conditions
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#      Year    Stage         Stadium         City Home Team Name  \
# 0  1930.0  Group 1         Pocitos  Montevideo          France
# 1  1930.0  Group 4  Parque Central  Montevideo             USA
# 2  1930.0  Group 2  Parque Central  Montevideo      Yugoslavia
# 3  1930.0  Group 3         Pocitos  Montevideo         Romania
# 4  1930.0  Group 1  Parque Central  Montevideo       Argentina
#
#    Home Team Goals  Away Team Goals Away Team Name Win conditions
# 0              4.0              1.0         Mexico
# 1              3.0              0.0        Belgium
# 2              2.0              1.0         Brazil
# 3              3.0              1.0           Peru
# 4              1.0              0.0         France

# %%
df.iloc[0,1:4]
# Out:
# Stage          Group 1
# Stadium        Pocitos
# City       Montevideo
# Name: 0, dtype: object

# %%
a=df.groupby("Home Team Name")["Home Team Goals"].sum()
a
# Out:
# Home Team Name
# Algeria                         5.0
# Angola                          0.0
# Argentina                     133.0
# Australia                      11.0
# Austria                        34.0
#                               ...
# rn">Bosnia and Herzegovina      3.0
# rn">Republic of Ireland         2.0
# rn">Serbia and Montenegro       0.0
# rn">Trinidad and Tobago         0.0
# rn">United Arab Emirates        0.0
# Name: Home Team Goals, Length: 92, dtype: float64

# %%
a.sort_values(ascending=False)
# Out:
# Home Team Name
# Brazil                       196.0
# Argentina                    133.0
# France                       101.0
# Italy                         99.0
# Germany FR                    99.0
#                              ...
# Cabo Verde                     0.0
# Angola                         0.0
# rn">Serbia and Montenegro      0.0
# rn">Trinidad and Tobago        0.0
# rn">United Arab Emirates       0.0
# Name: Home Team Goals, Length: 92, dtype: float64

# %%
b=df.groupby("Away Team Name")["Away Team Goals"].sum()
b
# Out:
# Away Team Name
# Algeria                        8.0
# Angola                         1.0
# Argentina                     33.0
# Australia                      9.0
# Austria                       12.0
#                               ...
# rn">Bosnia and Herzegovina     1.0
# rn">Republic of Ireland        8.0
# rn">Serbia and Montenegro      2.0
# rn">Trinidad and Tobago        0.0
# rn">United Arab Emirates       2.0
# Name: Away Team Goals, Length: 96, dtype: float64

# %%
b.sort_values(ascending=False)
# Out:
# Away Team Name
# France                     52.0
# Brazil                     51.0
# Spain                      51.0
# England                    47.0
# Mexico                     43.0
#                            ...
# Iraq                        0.0
# Zaire                       0.0
# Bolivia                     0.0
# rn">Trinidad and Tobago     0.0
# Türkiye                     0.0
# Name: Away Team Goals, Length: 96, dtype: float64

# %%
extra = df["Win conditions"].str.contains("extra time", case=False).sum()
penalties = df["Win conditions"].str.contains("penalties", case=False).sum()

print("Extra Time :", extra)
print("Penalties :", penalties)
# Out:
# Extra Time : 34
# Penalties : 39

# %%
df["Home Team Goals"].value_counts()
# Out:
# Home Team Goals
# 1.0     312
# 2.0     248
# 0.0     228
# 3.0     140
# 4.0      70
# 5.0      22
# 6.0      21
# 7.0      10
# 8.0       4
# 9.0       2
# 10.0      1
# Name: count, dtype: int64

# %%
a=df["City"].value_counts()
a
# Out:
# City
# Mexico City        23
# Al Rayyan          23
# Montevideo         18
# Guadalajara        17
# Rio De Janeiro     15
#                    ..
# Antibes             1
# Lugano              1
# Eskilstuna          1
# Orebro              1
# Foxborough          1
# Name: count, Length: 187, dtype: int64

# %%
a.max()
# Out:
# 23

# %%
a=df.groupby("Home Team Name")["Away Team Name"].value_counts()
a
# Out:
# Home Team Name             Away Team Name
# Algeria                    Austria             1
#                            Chile               1
#                            Northern Ireland    1
#                            Russia              1
#                            Slovenia            1
#                                               ..
# rn">Republic of Ireland    Norway              1
#                            Romania             1
# rn">Serbia and Montenegro  Netherlands         1
# rn">Trinidad and Tobago    Sweden              1
# rn">United Arab Emirates   Colombia            1
# Name: count, Length: 833, dtype: int64

# %%
a=df.groupby("Stage")["Win conditions"].value_counts()
a
# Out:
# Stage              Win conditions
# Final                                                  12
#                    Argentina win after extra time       1
#                    Brazil win on penalties (3 - 2)      1
#                    England win after extra time         1
#                    Germany win after extra time         1
#                                                        ..
# round of 16        Morocco win on penalties (3 - 0)     1
#                    Russia win on penalties (4 - 3)      1
# semi-finals                                             3
#                    Croatia win after extra time         1
# third-place match                                       2
# Name: count, Length: 103, dtype: int64

# %%
df[df["Stage"]=="Final"]
# Out:
#        Year  Stage                                            Stadium  \
# 17   1930.0  Final                                 Estadio Centenario
# 34   1934.0  Final                                      Nazionale PNF
# 52   1938.0  Final                                    Stade Olympique
# 100  1954.0  Final                                   Wankdorf Stadium
# 135  1958.0  Final                                    Rasunda Stadium
# 167  1962.0  Final                                           Nacional
# 199  1966.0  Final                                    Wembley Stadium
# 231  1970.0  Final                                     Estadio Azteca
# 269  1974.0  Final                                     Olympiastadion
# 307  1978.0  Final  El Monumental - Estadio Monumental Antonio Ves...
# 359  1982.0  Final                                  Santiago Bernabeu
# 411  1986.0  Final                                     Estadio Azteca
# ...

# %%
df["Home Team Goals"].max()
# Out:
# 10.0

# %%
df["Home Team Goals"].min()
# Out:
# 0.0

# %%
df["Away Team Goals"].max()
# Out:
# 7.0

# %%
df["Away Team Goals"].min()
# Out:
# 0.0

# %%
df["Total goals"]=df["Home Team Goals"]+df["Away Team Goals"]

# %%
df.head()
# Out:
#      Year    Stage         Stadium         City Home Team Name  \
# 0  1930.0  Group 1         Pocitos  Montevideo          France
# 1  1930.0  Group 4  Parque Central  Montevideo             USA
# 2  1930.0  Group 2  Parque Central  Montevideo      Yugoslavia
# 3  1930.0  Group 3         Pocitos  Montevideo         Romania
# 4  1930.0  Group 1  Parque Central  Montevideo       Argentina
#
#    Home Team Goals  Away Team Goals Away Team Name Win conditions  Total goals
# 0              4.0              1.0         Mexico                         5.0
# 1              3.0              0.0        Belgium                         3.0
# 2              2.0              1.0         Brazil                         3.0
# 3              3.0              1.0           Peru                         4.0
# 4              1.0              0.0         France                         1.0

# %%
def Winner(row):
    if row["Home Team Goals"]> row ["Away Team Goals"]:
        return row["Home Team Name"]
    elif row["Home Team Goals"] < row ["Away Team Goals"]:
        return row["Away Team Name"]
    else :
        return "Draw"
df["Winner"]=df.apply(Winner,axis=1)

# %%
df.sample(5)
# Out:
#        Year        Stage                 Stadium  \
# 360  1986.0      Group A          Estadio Azteca
# 42   1938.0  First round         Stade Municipal
# 728  2010.0      Group D  Port Elizabeth Stadium
# 359  1982.0        Final       Santiago Bernabeu
# 760  2010.0  Round of 16          Durban Stadium
#
#                                    City Home Team Name  Home Team Goals  \
# 360                        Mexico City        Bulgaria              1.0
# 42                            Toulouse            Cuba              2.0
# 728  Nelson Mandela Bay/Port Elizabeth         Germany              0.0
# 359                             Madrid           Italy              3.0
# 760                             Durban     Netherlands              2.0
#
#      Away Team Goals Away Team Name Win conditions  Total goals       Winner
# 360              1.0          Italy                         2.0         Draw
# 42               1.0        Romania                         3.0         Cuba
# ...

# %%
wins=df["Winner"].value_counts()
print(wins)
# Out:
# Winner
# Draw              235
# Brazil             79
# Argentina          52
# Italy              45
# France             44
#                  ...
# Czech Republic      1
# Jamaica             1
# Cuba                1
# Wales               1
# Türkiye             1
# Name: count, Length: 73, dtype: int64

# %%
df.to_csv("new_fifa_world_cup.csv",index=False)
