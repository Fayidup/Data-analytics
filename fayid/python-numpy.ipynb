# %% [markdown]
# ## NUMPY

# %%
import numpy as np

# %% [markdown]
# ## 1 D Array

# %%
a = np.array([10,20,30,50,60,0])
a.dtype
# Out:
# dtype('int32')

# %%
a.shape
# Out:
# (6,)

# %%
a.ndim
# Out:
# 1

# %%
a.size
# Out:
# 6

# %%
a[3]
# Out:
# 50

# %%
a[2]
# Out:
# 30

# %% [markdown]
# ## MULTI DYMENSIONAL ARRAY

# %%
a_2d =np.array([[2,4,6,8], [1,3,5,7]])
a_2d
# Out:
# array([[2, 4, 6, 8],
#        [1, 3, 5, 7]])

# %%
a_2d.dtype
# Out:
# dtype('int32')

# %%
a_2d.shape
# Out:
# (2, 4)

# %%
a_2d.size
# Out:
# 8

# %%
a_2d.ndim
# Out:
# 2

# %%
a[1]
# Out:
# 20
