# %%
import numpy as np

# %% [markdown]
# ## 1 D ARRAY

# %%
a= np.array([0,5,10,15,20,25])
a.dtype
# Out:
# dtype('int32')

# %%
a.shape
# Out:
# (6,)

# %%
a.size
# Out:
# 6

# %%
a.ndim
# Out:
# 1

# %%
a[3]
# Out:
# 15

# %% [markdown]
# ## 2 D ARRAY

# %%
a_2d= np.array([[5,10,15], [10,20,30]])
a_2d
# Out:
# array([[ 5, 10, 15],
#        [10, 20, 30]])

# %%
a_2d.shape
# Out:
# (2, 3)

# %%
a_2d.size
# Out:
# 6

# %%
a_2d.ndim
# Out:
# 2

# %%
a_2d[1]
# Out:
# array([10, 20, 30])
